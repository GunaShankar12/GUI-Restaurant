# %%
from tkinter import *

def create():
    master=Toplevel(root)
    master.geometry("1200x700")
    master.title("Menu")

    labelframe_bill=LabelFrame(master,width=350,height=700,highlightthickness=5,highlightbackground='#BC986A',bg='#FBEEC1').place(x=850)
    labelframe_menu=LabelFrame(master,width=850,height=700,bg='#432616').place(x=0)
    label_menu=Label(master,text='MENU',bg='#432616',fg='#FFFFFF',font=('times',40,'bold')).place(x=350,y=25)
    
    starters=Label(master,text='STARTERS',bg='#432616',fg='#F4A460',font=('times',30,'bold','underline')).place(x=40,y=80)
    var1 = IntVar()
    var2 = IntVar()
    var3 = IntVar()
    check_box_1=Checkbutton(master,text='Tomato Soup',variable=var1,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_1.place(x=40,y=135)
    Label_1_rate=Label(master,text='80',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_1_rate.place(x=240,y=138)
    check_box_2=Checkbutton(master,text='Chicken Soup',variable=var2,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_2.place(x=40,y=170)
    Label_2_rate=Label(master,text='120',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_2_rate.place(x=240,y=173)
    check_box_3=Checkbutton(master,text='Crispy Corn',variable=var3,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_3.place(x=40,y=205)
    Label_3_rate=Label(master,text='100',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_3_rate.place(x=240,y=208)
    
    salads=Label(master,text='SALADS',bg='#432616',fg='#F4A460',font=('times',30,'bold','underline')).place(x=40,y=250)
    var4 = IntVar()
    var5 = IntVar()
    var6 = IntVar()
    check_box_4=Checkbutton(master,text='Guacamole Salad',variable=var4,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_4.place(x=40,y=305)
    Label_4_rate=Label(master,text='120',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_4_rate.place(x=240,y=308)
    check_box_5=Checkbutton(master,text='Chicken Salad',variable=var5,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_5.place(x=40,y=340)
    Label_5_rate=Label(master,text='125',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_5_rate.place(x=240,y=343)
    
    main_course=Label(master,text='MAIN COURSES',bg='#432616',fg='#F4A460',font=('times',30,'bold','underline')).place(x=40,y=390)
    var6 = IntVar()
    var7 = IntVar()
    var8 = IntVar()
    var9 = IntVar()
    check_box_6=Checkbutton(master,text='Grilled Fish',variable=var6,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_6.place(x=40,y=445)
    Label_6_rate=Label(master,text='280',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_6_rate.place(x=240,y=448)
    check_box_7=Checkbutton(master,text='Chicken&Rice',variable=var7,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_7.place(x=40,y=480)
    Label_7_rate=Label(master,text='300',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_7_rate.place(x=240,y=483)
    check_box_8=Checkbutton(master,text='Turkry Pie',variable=var8,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_8.place(x=40,y=515)
    Label_8_rate=Label(master,text='340',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_8_rate.place(x=240,y=518)
    check_box_9=Checkbutton(master,text='Veg Pasta',variable=var5,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_9.place(x=40,y=550)
    Label_9_rate=Label(master,text='320',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_9_rate.place(x=240,y=553)
    
    dessert=Label(master,text='DESSERTS',bg='#432616',fg='#F4A460',font=('times',30,'bold','underline')).place(x=550,y=80)
    var10 = IntVar()
    var11 = IntVar()
    var12 = IntVar()
    var13 = IntVar()
    var14 = IntVar()
    check_box_10=Checkbutton(master,text='Fruit & Cream',variable=var10,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_10.place(x=550,y=135)
    Label_10_rate=Label(master,text='180',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_10_rate.place(x=750,y=138)
    check_box_11=Checkbutton(master,text='Ice Cream',variable=var11,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_11.place(x=550,y=170)
    Label_11_rate=Label(master,text='160',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_11_rate.place(x=750,y=178)
    check_box_12=Checkbutton(master,text='Chocolate Cake',variable=var12,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_12.place(x=550,y=205)
    Label_12_rate=Label(master,text='220',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_12_rate.place(x=750,y=208)
    check_box_13=Checkbutton(master,text='Strawberry Cake',variable=var13,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_13.place(x=550,y=240)
    Label_13_rate=Label(master,text='240',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_13_rate.place(x=750,y=243)
    check_box_14=Checkbutton(master,text='Apple Pie',variable=var14,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_14.place(x=550,y=275)
    Label_14_rate=Label(master,text='260',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_14_rate.place(x=750,y=278)
    
    drinks=Label(master,text='DRINKS',bg='#432616',fg='#F4A460',font=('times',30,'bold','underline')).place(x=550,y=325)
    var15 = IntVar()
    var16 = IntVar()
    var17 = IntVar()
    var18 = IntVar()
    var19 = IntVar()
    check_box_15=Checkbutton(master,text='Mineral Water',variable=var15,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_15.place(x=550,y=380)
    Label_15_rate=Label(master,text='20',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_15_rate.place(x=750,y=383)
    check_box_16=Checkbutton(master,text='Fruit Juice',variable=var16,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_16.place(x=550,y=415)
    Label_16_rate=Label(master,text='100',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_16_rate.place(x=750,y=418)
    check_box_17=Checkbutton(master,text='Coffee',variable=var17,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_17.place(x=550,y=450)
    Label_17_rate=Label(master,text='70',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_17_rate.place(x=750,y=458)
    check_box_18=Checkbutton(master,text='Tea',variable=var18,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_18.place(x=550,y=485)
    Label_18_rate=Label(master,text='20',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_18_rate.place(x=750,y=488)
    check_box_19=Checkbutton(master,text='Wines',variable=var19,font=('times',15,'bold'),bg='#432616',fg='#FFFFFF')
    check_box_19.place(x=550,y=520)
    Label_19_rate=Label(master,text='260',bg='#432616',fg='#FFFFFF',font=('times',15,'bold'))
    Label_19_rate.place(x=750,y=528)
    
    entry_4=IntVar()
    entry_5=IntVar()
    entry_6=IntVar()
    entry_7=IntVar()
    entry_8=IntVar()
    entry_9=IntVar()
    entry_10=IntVar()
    entry_11=IntVar()
    entry_12=IntVar()
    entry_13=IntVar()
    entry_14=IntVar()
    entry_15=IntVar()
    entry_16=IntVar()
    entry_17=IntVar()
    entry_18=IntVar()
    entry_19=IntVar()
    entry_20=IntVar()
    entry_21=IntVar()
    entry_22=IntVar()
    
    def var_states():
        x1=875;y1=145
        x2=1020;y2=145
        x3=1090;y3=145
        if var1.get():
            Label(master,text=check_box_1['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_1_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_4).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var2.get():
            Label(master,text=check_box_2['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_2_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_5).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var3.get():
            Label(master,text=check_box_3['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_3_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_6).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var4.get():
            Label(master,text=check_box_4['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_4_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_7).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var5.get():
            Label(master,text=check_box_5['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_5_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_8).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var6.get():
            Label(master,text=check_box_6['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_6_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_9).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var7.get():
            Label(master,text=check_box_7['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_7_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_10).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var8.get():
            Label(master,text=check_box_8['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_8_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_11).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var9.get():
            Label(master,text=check_box_9['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_9_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_12).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var10.get():
            Label(master,text=check_box_10['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_10_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_13).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var11.get():
            Label(master,text=check_box_11['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_11_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_14).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var12.get():
            Label(master,text=check_box_12['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_12_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_15).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var13.get():
            Label(master,text=check_box_13['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_13_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_16).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var14.get():
            Label(master,text=check_box_14['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_14_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_17).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var15.get():
            Label(master,text=check_box_15['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_15_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_18).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var16.get():
            Label(master,text=check_box_16['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_16_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_19).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var17.get():
            Label(master,text=check_box_17['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_17_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_20).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var18.get():
            Label(master,text=check_box_18['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_18_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_21).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
        if var19.get():
            Label(master,text=check_box_19['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x1,y=y1)
            Label(master,text=Label_19_rate['text'],fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x2,y=y2)
            Entry(master,width=2,textvariable=entry_22).place(x=x3,y=y3)
            y1=y1+20
            y2=y2+20
            y3=y3+20
    def set_value():
        x4=1135;y4=145
        Total=0
        if var1.get():
            price=int(Label_1_rate['text'])
            value=price*entry_4.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var2.get():
            price=int(Label_2_rate['text'])
            value=price*entry_5.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var3.get():
            price=int(Label_3_rate['text'])
            value=price*entry_6.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var4.get():
            price=int(Label_4_rate['text'])
            value=price*entry_7.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var5.get():
            price=int(Label_5_rate['text'])
            value=price*entry_8.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var6.get():
            price=int(Label_6_rate['text'])
            value=price*entry_9.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var7.get():
            price=int(Label_7_rate['text'])
            value=price*entry_10.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var8.get():
            price=int(Label_8_rate['text'])
            value=price*entry_11.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var9.get():
            price=int(Label_9_rate['text'])
            value=price*entry_12.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var10.get():
            price=int(Label_10_rate['text'])
            value=price*entry_13.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var11.get():
            price=int(Label_11_rate['text'])
            value=price*entry_14.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var12.get():
            price=int(Label_12_rate['text'])
            value=price*entry_15.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var13.get():
            price=int(Label_13_rate['text'])
            value=price*entry_17.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var14.get():
            price=int(Label_14_rate['text'])
            value=price*entry_17.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var15.get():
            price=int(Label_15_rate['text'])
            value=price*entry_18.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var16.get():
            price=int(Label_16_rate['text'])
            value=price*entry_19.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var17.get():
            price=int(Label_17_rate['text'])
            value=price*entry_20.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var18.get():
            price=int(Label_18_rate['text'])
            value=price*entry_21.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        if var19.get():
            price=int(Label_19_rate['text'])
            value=price*entry_22.get()
            Total+=value
            Label(master,text=value,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4)
            y4=y4+20
        Label(master,text='TOTAL',fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4-70,y=y4+30)
        Label(master,text=Total,fg='#000000',bg='#FBEEC1',font=('times',13,'bold')).place(x=x4,y=y4+30) 

    button=Button(master,text='SUBMIT',bg='#432616',fg='#F4A460',font=('times',20,'bold'),command=var_states).place(x=350,y=550)    
    
    butn=Button(master,text='Submit',bg='#FBEEC1',fg='#F4A460',font=('times',15,'bold'),command=set_value).place(x=1000,y=600) 
    
    label_bill=Label(master,text='BILL',fg='#432616',bg='#FBEEC1',font=('times',30,'bold')).place(x=975,y=15)
    
    label_name=Label(master,text=entry_1.get(),fg='#BC986A',bg='#FBEEC1',font=('times',15,'bold')).place(x=875,y=60)
    label_mobile=Label(master,text=entry_2.get(),fg='#BC986A',bg='#FBEEC1',font=('times',15,'bold')).place(x=875,y=90)
    label_date=Label(master,text=entry_3.get(),fg='#BC986A',bg='#FBEEC1',font=('times',15,'bold')).place(x=1075,y=70)
    
    Label(master,text='ITEM',fg='#432616',bg='#FBEEC1',font=('times',15,'bold')).place(x=900,y=115)
    Label(master,text='Price',fg='#432616',bg='#FBEEC1',font=('times',15,'bold')).place(x=1010,y=115)
    Label(master,text='Qty',fg='#432616',bg='#FBEEC1',font=('times',15,'bold')).place(x=1080,y=115)
    
root = Tk()
root.geometry("1200x700")
root.title("Restaurant")
root.config(bg="#5CDB95")

Label(root,text="Welcome To ",font=('times',35,'bold'),fg="#05386B",bg="#5CDB95").place(x=385,y=60)

Label(root,text="Al FAHAM RESTAURANT",font=('times',40,'bold'),fg="#05386B",bg="#5CDB95").place(x=250,y=130)

Label(root,text='Name',font=('arial',20,'bold'),fg="#EDF5E1",bg="#5CDB95").place(x=300,y=210)

entry_1=StringVar()
Entry(root,width=50,textvariable=entry_1).place(x=440,y=220)

Label(root,text='Mobile No.',font=('arial',20,'bold'),fg="#EDF5E1",bg="#5CDB95").place(x=300,y=250)

entry_2=StringVar()
Entry(root,width=50,textvariable=entry_2).place(x=440,y=260)

Label(root,text='Date',font=('arial',20,'bold'),fg="#EDF5E1",bg="#5CDB95").place(x=300,y=290)

entry_3=StringVar()
Entry(root,width=50,textvariable=entry_3).place(x=440,y=300)

Label(root,text='Address',font=('arial',20,'bold'),fg="#EDF5E1",bg="#5CDB95").place(x=300,y=330)

Text(root,height=5,width=60).place(x=440,y=340)

Button(root,text="Continue",width=10,font=('times',30,'bold'),command=create,bg="#05386B",fg='#5CDB95').place(x=390,y=490)

root.mainloop()
